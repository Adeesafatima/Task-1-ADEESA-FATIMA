# %%
# To-Do List

tasks = []

while True:
    print("\n===== TO-DO LIST MENU =====")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Exit")

    choice = input("Enter your choice (1-3): ")

    if choice == "1":
        task = input("Enter a new task: ")
        tasks.append(task)
        print("Task added successfully!")

    elif choice == "2":
        if len(tasks) == 0:
            print("No tasks available.")
        else:
            print("\nYour Tasks:")
            for i, task in enumerate(tasks, start=1):
                print(f"{i}. {task}")

    elif choice == "3":
        print("Exiting To-Do List. Goodbye!")
        break

    else:
        print("Invalid choice! Please enter 1, 2, or 3.")
# Out:
# ===== TO-DO LIST MENU =====
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Enter your choice (1-3): 1
# Enter a new task: I have to write an email
# Task added successfully!
#
# ===== TO-DO LIST MENU =====
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Enter your choice (1-3): 2
#
# Your Tasks:
# 1. I have to write an email
#
# ===== TO-DO LIST MENU =====
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Enter your choice (1-3): 3
# Exiting To-Do List. Goodbye!
